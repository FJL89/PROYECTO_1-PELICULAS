# %%
import pandas as pd
import numpy as np

# %%
dfFinal = pd.read_csv(r'DATOS/dfFinal.csv')
ratings = pd.read_csv(r'DATOS/ratings.csv')

# %%
#CUENTO LAS FILAS DEL CSV RAITINGS
num_filas = ratings.shape[0]
print("El dataframe tiene", num_filas, "filas.")
# Out:
# El dataframe tiene 9524289 filas.

# %%
#BORRO FILAS DUPLICADAS YA QUE TENGO LOS PROMEDIOS
ratings = ratings.drop_duplicates(subset=['id'])

# %%
#UNO EL ARCHIVO CON EL DF FINAL
dfUnido1 = pd.merge(dfFinal, ratings, on='id')

# %%
#LO MUESTRO
dfUnido1
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x show_id     type  \
# 0                 0             0             0      s1    movie
# 1             14191         14191         14191      s1    movie
# 2                 1             1             1      s2    movie
# 3             14192         14192         14192      s2    movie
# 4                 2             2             2      s3    movie
# ...             ...           ...           ...     ...      ...
# 22132         14186         14186         14186   s3069  tv show
# 22133         14187         14187         14187   s3070  tv show
# 22134         14188         14188         14188   s3071  tv show
# 22135         14189         14189         14189   s3072  tv show
# 22136         14190         14190         14190   s3073  tv show
#
#                                 title      director  \
# 0                 the grand seduction  don mckellar
# 1                 the grand seduction  don mckellar
# ...

# %%
num_filas = ratings.shape[0]
print("El dataframe tiene", num_filas, "filas.")
# Out:
# El dataframe tiene 22998 filas.

# %%
dfFinal
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 show_id     type  \
# 0                 0             0           0      s1    movie
# 1                 1             1           1      s2    movie
# 2                 2             2           2      s3    movie
# 3                 3             3           3      s4    movie
# 4                 4             4           4      s5    movie
# ...             ...           ...         ...     ...      ...
# 23854         23854         23854       23854   s9664    movie
# 23855         23855         23855       23855   s9665  tv show
# 23856         23856         23856       23856   s9666    movie
# 23857         23857         23857       23857   s9667  tv show
# 23858         23858         23858       23858   s9668    movie
#
#                          title         director  \
# 0          the grand seduction     don mckellar
# 1         take care good night     girish joshi
# 2         secrets of deception      josh webber
# ...

# %% [markdown]
# DROPEO COLUMNAS INNECESARIAS

# %%
dfUnido1 = dfUnido1.drop(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0_x'], axis=1)

# %%
dfFinal = dfFinal.drop(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
dfUnido1
# Out:
#       show_id     type                           title      director  \
# 0          s1    movie             the grand seduction  don mckellar
# 1          s1    movie             the grand seduction  don mckellar
# 2          s2    movie            take care good night  girish joshi
# 3          s2    movie            take care good night  girish joshi
# 4          s3    movie            secrets of deception   josh webber
# ...       ...      ...                             ...           ...
# 22132   s3069  tv show  star trek: the original series           NaN
# 22133   s3070  tv show              star trek: voyager           NaN
# 22134   s3071  tv show                       the fades           NaN
# 22135   s3072  tv show               the twilight zone           NaN
# 22136   s3073  tv show             tokyo magnitude 8.0           NaN
#
#                                                     cast         country  \
# ...

# %%
dfFinal.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  movie   the grand seduction    don mckellar
# 1      s2  movie  take care good night    girish joshi
# 2      s3  movie  secrets of deception     josh webber
# 3      s4  movie    pink: staying true  sonia anderson
# 4      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#    date_added  release_year rating duration                listed_in  \
# 0  2021-03-30          2014      g  113 min            comedy, drama
# 1  2021-03-30          2018    13+  110 min     drama, international
# ...

# %%
dfUnido1 = dfUnido1.drop(['rating_y','userId','Unnamed: 0_y'], axis=1)

# %%
dfUnido1
# Out:
#       show_id     type                           title      director  \
# 0          s1    movie             the grand seduction  don mckellar
# 1          s1    movie             the grand seduction  don mckellar
# 2          s2    movie            take care good night  girish joshi
# 3          s2    movie            take care good night  girish joshi
# 4          s3    movie            secrets of deception   josh webber
# ...       ...      ...                             ...           ...
# 22132   s3069  tv show  star trek: the original series           NaN
# 22133   s3070  tv show              star trek: voyager           NaN
# 22134   s3071  tv show                       the fades           NaN
# 22135   s3072  tv show               the twilight zone           NaN
# 22136   s3073  tv show             tokyo magnitude 8.0           NaN
#
#                                                     cast         country  \
# ...

# %%
#GUARDO LOS ARCHIVOS
dfFinal.to_csv(r'DATOS/dfFinal.csv')
dfUnido1.to_csv(r'DATOS/DFFINAL_PARA_CONSULTAS.csv')
